# %%
import numpy as np
import cv2
from PIL import ImageGrab
import os,datetime,time , sys
import time
print ("Package loaded") 

ts = time.time()
# Convert time (in seconds) into a string
date = datetime.datetime.fromtimestamp(ts).strftime('%Y-%m-%d %H_%M_%S')
# create Folder with Timestamp
os.mkdir('images_ %s' %date)

# Load CascadeClassifier to detect Faces -> frontalface.default.xml file)
face_cascade=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

imageCount = 1
piclimit = 100
saveCount=0
while(1):
    img = ImageGrab.grab(bbox = (30,170,910,680))
    img_np = np.array(img)
    frame = cv2. cvtColor(img_np, cv2.COLOR_BGR2RGB)
    
    #Detect face in the gray frame
    faces=face_cascade.detectMultiScale(frame)

    faceCaptured = 0
    # defines a list called crop_img 
    crop_img=[None]

    
    for(x,y,w,h) in faces:
        if((w>100)and(h>100)):
            cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)
            faceCaptured+=1
            crop_img.append(cv2.resize(frame[y+2:y+h-1,x+2:x+w-1],(250,250)))

    if (faceCaptured>0):
        cv2.imwrite('images_ %s/' %date +str(saveCount)+'.png',crop_img[1])
        saveCount +=1
        print("Number of saved pictures: [%s von %d]" %(saveCount,piclimit))

            
    cv2.imshow("frame",frame)
    key = cv2.waitKey(1)
    if key == 27:
        break
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Package loaded
# Number of saved pictures: [1 von 100]
# Number of saved pictures: [2 von 100]
# Number of saved pictures: [3 von 100]
# Number of saved pictures: [4 von 100]
# Number of saved pictures: [5 von 100]
# Number of saved pictures: [6 von 100]
# Number of saved pictures: [7 von 100]
# Number of saved pictures: [8 von 100]
# Number of saved pictures: [9 von 100]
# Number of saved pictures: [10 von 100]
# Number of saved pictures: [11 von 100]
# Number of saved pictures: [12 von 100]
# Number of saved pictures: [13 von 100]
# Number of saved pictures: [14 von 100]
# Number of saved pictures: [15 von 100]
# Number of saved pictures: [16 von 100]
# Number of saved pictures: [17 von 100]
# Number of saved pictures: [18 von 100]
# Number of saved pictures: [19 von 100]
# Number of saved pictures: [20 von 100]
# Number of saved pictures: [21 von 100]
# Number of saved pictures: [22 von 100]
# Number of saved pictures: [23 von 100]
# Number of saved pictures: [24 von 100]
# Number of saved pictures: [25 von 100]
# Number of saved pictures: [26 von 100]
# Number of saved pictures: [27 von 100]
# Number of saved pictures: [28 von 100]
# Number of saved pictures: [29 von 100]
# Number of saved pictures: [30 von 100]
# Number of saved pictures: [31 von 100]
# Number of saved pictures: [32 von 100]
# Number of saved pictures: [33 von 100]
# Number of saved pictures: [34 von 100]
# Number of saved pictures: [35 von 100]
# Number of saved pictures: [36 von 100]
# Number of saved pictures: [37 von 100]
# Number of saved pictures: [38 von 100]
# Number of saved pictures: [39 von 100]
# Number of saved pictures: [40 von 100]
# Number of saved pictures: [41 von 100]
# Number of saved pictures: [42 von 100]
# Number of saved pictures: [43 von 100]
# Number of saved pictures: [44 von 100]
# Number of saved pictures: [45 von 100]
# Number of saved pictures: [46 von 100]
# Number of saved pictures: [47 von 100]
# Number of saved pictures: [48 von 100]
# Number of saved pictures: [49 von 100]
# Number of saved pictures: [50 von 100]
# Number of saved pictures: [51 von 100]
# Number of saved pictures: [52 von 100]
# Number of saved pictures: [53 von 100]
# Number of saved pictures: [54 von 100]
# Number of saved pictures: [55 von 100]
# Number of saved pictures: [56 von 100]
# Number of saved pictures: [57 von 100]
# Number of saved pictures: [58 von 100]
# Number of saved pictures: [59 von 100]
# Number of saved pictures: [60 von 100]
# Number of saved pictures: [61 von 100]
# Number of saved pictures: [62 von 100]
# Number of saved pictures: [63 von 100]
# Number of saved pictures: [64 von 100]
# Number of saved pictures: [65 von 100]
# Number of saved pictures: [66 von 100]
# Number of saved pictures: [67 von 100]
# Number of saved pictures: [68 von 100]
# Number of saved pictures: [69 von 100]
# Number of saved pictures: [70 von 100]
# Number of saved pictures: [71 von 100]
# Number of saved pictures: [72 von 100]
# Number of saved pictures: [73 von 100]
# Number of saved pictures: [74 von 100]
# Number of saved pictures: [75 von 100]
# Number of saved pictures: [76 von 100]
# Number of saved pictures: [77 von 100]
# Number of saved pictures: [78 von 100]
# Number of saved pictures: [79 von 100]
# Number of saved pictures: [80 von 100]
# Number of saved pictures: [81 von 100]
# Number of saved pictures: [82 von 100]
# Number of saved pictures: [83 von 100]
# Number of saved pictures: [84 von 100]
# Number of saved pictures: [85 von 100]
# Number of saved pictures: [86 von 100]
# Number of saved pictures: [87 von 100]
# Number of saved pictures: [88 von 100]
# Number of saved pictures: [89 von 100]
# Number of saved pictures: [90 von 100]
# Number of saved pictures: [91 von 100]
# Number of saved pictures: [92 von 100]
# Number of saved pictures: [93 von 100]
# Number of saved pictures: [94 von 100]
# Number of saved pictures: [95 von 100]
# Number of saved pictures: [96 von 100]
# Number of saved pictures: [97 von 100]
# Number of saved pictures: [98 von 100]
# Number of saved pictures: [99 von 100]
# Number of saved pictures: [100 von 100]
# Number of saved pictures: [101 von 100]
# Number of saved pictures: [102 von 100]
# Number of saved pictures: [103 von 100]
# Number of saved pictures: [104 von 100]
# Number of saved pictures: [105 von 100]
# Number of saved pictures: [106 von 100]
# Number of saved pictures: [107 von 100]
# Number of saved pictures: [108 von 100]
# Number of saved pictures: [109 von 100]
# Number of saved pictures: [110 von 100]
# Number of saved pictures: [111 von 100]
# Number of saved pictures: [112 von 100]
# Number of saved pictures: [113 von 100]
# Number of saved pictures: [114 von 100]
# Number of saved pictures: [115 von 100]
# Number of saved pictures: [116 von 100]
# Number of saved pictures: [117 von 100]
# Number of saved pictures: [118 von 100]
# Number of saved pictures: [119 von 100]
# Number of saved pictures: [120 von 100]
# Number of saved pictures: [121 von 100]
# Number of saved pictures: [122 von 100]
# Number of saved pictures: [123 von 100]
# Number of saved pictures: [124 von 100]
# Number of saved pictures: [125 von 100]
# Number of saved pictures: [126 von 100]
# Number of saved pictures: [127 von 100]
# Number of saved pictures: [128 von 100]
# Number of saved pictures: [129 von 100]
# Number of saved pictures: [130 von 100]
# Number of saved pictures: [131 von 100]
# Number of saved pictures: [132 von 100]
# Number of saved pictures: [133 von 100]
# Number of saved pictures: [134 von 100]
# Number of saved pictures: [135 von 100]
# Number of saved pictures: [136 von 100]
# Number of saved pictures: [137 von 100]
# Number of saved pictures: [138 von 100]
# Number of saved pictures: [139 von 100]
# Number of saved pictures: [140 von 100]
# Number of saved pictures: [141 von 100]
# Number of saved pictures: [142 von 100]
# Number of saved pictures: [143 von 100]
# Number of saved pictures: [144 von 100]
# Number of saved pictures: [145 von 100]
# Number of saved pictures: [146 von 100]
# Number of saved pictures: [147 von 100]
# Number of saved pictures: [148 von 100]
# Number of saved pictures: [149 von 100]
# Number of saved pictures: [150 von 100]
# Number of saved pictures: [151 von 100]
# Number of saved pictures: [152 von 100]
# Number of saved pictures: [153 von 100]
# Number of saved pictures: [154 von 100]
# Number of saved pictures: [155 von 100]
# Number of saved pictures: [156 von 100]
# Number of saved pictures: [157 von 100]
# Number of saved pictures: [158 von 100]
# Number of saved pictures: [159 von 100]
# Number of saved pictures: [160 von 100]
# Number of saved pictures: [161 von 100]
# Number of saved pictures: [162 von 100]
# Number of saved pictures: [163 von 100]
# Number of saved pictures: [164 von 100]
# Number of saved pictures: [165 von 100]
# Number of saved pictures: [166 von 100]
# Number of saved pictures: [167 von 100]
# Number of saved pictures: [168 von 100]
# Number of saved pictures: [169 von 100]
# Number of saved pictures: [170 von 100]
# Number of saved pictures: [171 von 100]
# Number of saved pictures: [172 von 100]
# Number of saved pictures: [173 von 100]
# Number of saved pictures: [174 von 100]
# Number of saved pictures: [175 von 100]
# Number of saved pictures: [176 von 100]
# Number of saved pictures: [177 von 100]
# Number of saved pictures: [178 von 100]
# Number of saved pictures: [179 von 100]
# Number of saved pictures: [180 von 100]
# Number of saved pictures: [181 von 100]
# Number of saved pictures: [182 von 100]
# Number of saved pictures: [183 von 100]
# Number of saved pictures: [184 von 100]
# Number of saved pictures: [185 von 100]
# Number of saved pictures: [186 von 100]
# Number of saved pictures: [187 von 100]
# Number of saved pictures: [188 von 100]
# Number of saved pictures: [189 von 100]
# Number of saved pictures: [190 von 100]
# Number of saved pictures: [191 von 100]
# Number of saved pictures: [192 von 100]
# Number of saved pictures: [193 von 100]
# Number of saved pictures: [194 von 100]
# Number of saved pictures: [195 von 100]
# Number of saved pictures: [196 von 100]
# Number of saved pictures: [197 von 100]
# Number of saved pictures: [198 von 100]
# Number of saved pictures: [199 von 100]
# Number of saved pictures: [200 von 100]
# Number of saved pictures: [201 von 100]
# Number of saved pictures: [202 von 100]
# Number of saved pictures: [203 von 100]
# Number of saved pictures: [204 von 100]
# Number of saved pictures: [205 von 100]
# Number of saved pictures: [206 von 100]
# Number of saved pictures: [207 von 100]
# Number of saved pictures: [208 von 100]
# Number of saved pictures: [209 von 100]
# Number of saved pictures: [210 von 100]
# Number of saved pictures: [211 von 100]
# Number of saved pictures: [212 von 100]
# Number of saved pictures: [213 von 100]
# Number of saved pictures: [214 von 100]
# Number of saved pictures: [215 von 100]
# Number of saved pictures: [216 von 100]
# Number of saved pictures: [217 von 100]
# Number of saved pictures: [218 von 100]
# Number of saved pictures: [219 von 100]
# Number of saved pictures: [220 von 100]
# Number of saved pictures: [221 von 100]
# Number of saved pictures: [222 von 100]
# Number of saved pictures: [223 von 100]
# Number of saved pictures: [224 von 100]
# Number of saved pictures: [225 von 100]
# Number of saved pictures: [226 von 100]
# Number of saved pictures: [227 von 100]
# Number of saved pictures: [228 von 100]
# Number of saved pictures: [229 von 100]
# Number of saved pictures: [230 von 100]
# Number of saved pictures: [231 von 100]
# Number of saved pictures: [232 von 100]
# Number of saved pictures: [233 von 100]
# Number of saved pictures: [234 von 100]
# Number of saved pictures: [235 von 100]
# Number of saved pictures: [236 von 100]
# Number of saved pictures: [237 von 100]
# Number of saved pictures: [238 von 100]
# Number of saved pictures: [239 von 100]
# Number of saved pictures: [240 von 100]
# Number of saved pictures: [241 von 100]
# Number of saved pictures: [242 von 100]
# Number of saved pictures: [243 von 100]
# Number of saved pictures: [244 von 100]
# Number of saved pictures: [245 von 100]
# Number of saved pictures: [246 von 100]
# Number of saved pictures: [247 von 100]
# Number of saved pictures: [248 von 100]
# Number of saved pictures: [249 von 100]
# Number of saved pictures: [250 von 100]
# Number of saved pictures: [251 von 100]
# Number of saved pictures: [252 von 100]
# Number of saved pictures: [253 von 100]
# Number of saved pictures: [254 von 100]
# Number of saved pictures: [255 von 100]
# Number of saved pictures: [256 von 100]
# Number of saved pictures: [257 von 100]
# Number of saved pictures: [258 von 100]
# Number of saved pictures: [259 von 100]
# Number of saved pictures: [260 von 100]
# Number of saved pictures: [261 von 100]
# Number of saved pictures: [262 von 100]
# Number of saved pictures: [263 von 100]
# Number of saved pictures: [264 von 100]
# Number of saved pictures: [265 von 100]
# Number of saved pictures: [266 von 100]
# Number of saved pictures: [267 von 100]
# Number of saved pictures: [268 von 100]
# Number of saved pictures: [269 von 100]
# Number of saved pictures: [270 von 100]
# Number of saved pictures: [271 von 100]
# Number of saved pictures: [272 von 100]
# Number of saved pictures: [273 von 100]
# Number of saved pictures: [274 von 100]
# Number of saved pictures: [275 von 100]
# Number of saved pictures: [276 von 100]
# Number of saved pictures: [277 von 100]
# Number of saved pictures: [278 von 100]
# Number of saved pictures: [279 von 100]
# Number of saved pictures: [280 von 100]
# Number of saved pictures: [281 von 100]
# Number of saved pictures: [282 von 100]
# Number of saved pictures: [283 von 100]
# Number of saved pictures: [284 von 100]
# Number of saved pictures: [285 von 100]
# Number of saved pictures: [286 von 100]
# Number of saved pictures: [287 von 100]
# Number of saved pictures: [288 von 100]
# Number of saved pictures: [289 von 100]
# Number of saved pictures: [290 von 100]
# Number of saved pictures: [291 von 100]
# Number of saved pictures: [292 von 100]
# Number of saved pictures: [293 von 100]
# Number of saved pictures: [294 von 100]
# Number of saved pictures: [295 von 100]
# Number of saved pictures: [296 von 100]
# Number of saved pictures: [297 von 100]
# Number of saved pictures: [298 von 100]
# Number of saved pictures: [299 von 100]
# Number of saved pictures: [300 von 100]
# Number of saved pictures: [301 von 100]
# Number of saved pictures: [302 von 100]
# Number of saved pictures: [303 von 100]
# Number of saved pictures: [304 von 100]
# Number of saved pictures: [305 von 100]
# Number of saved pictures: [306 von 100]
# Number of saved pictures: [307 von 100]
# Number of saved pictures: [308 von 100]
# Number of saved pictures: [309 von 100]
# Number of saved pictures: [310 von 100]
# Number of saved pictures: [311 von 100]
# Number of saved pictures: [312 von 100]
# Number of saved pictures: [313 von 100]
# Number of saved pictures: [314 von 100]
# Number of saved pictures: [315 von 100]
# Number of saved pictures: [316 von 100]
# Number of saved pictures: [317 von 100]
# Number of saved pictures: [318 von 100]
# Number of saved pictures: [319 von 100]
# Number of saved pictures: [320 von 100]
# Number of saved pictures: [321 von 100]
# Number of saved pictures: [322 von 100]
# Number of saved pictures: [323 von 100]
# Number of saved pictures: [324 von 100]
# Number of saved pictures: [325 von 100]
# Number of saved pictures: [326 von 100]
# Number of saved pictures: [327 von 100]
# Number of saved pictures: [328 von 100]
# Number of saved pictures: [329 von 100]
# Number of saved pictures: [330 von 100]
# Number of saved pictures: [331 von 100]
# Number of saved pictures: [332 von 100]
# Number of saved pictures: [333 von 100]
# Number of saved pictures: [334 von 100]
# Number of saved pictures: [335 von 100]
# Number of saved pictures: [336 von 100]
# Number of saved pictures: [337 von 100]
# Number of saved pictures: [338 von 100]
# Number of saved pictures: [339 von 100]
# Number of saved pictures: [340 von 100]
# Number of saved pictures: [341 von 100]
# Number of saved pictures: [342 von 100]
# Number of saved pictures: [343 von 100]
# Number of saved pictures: [344 von 100]
# Number of saved pictures: [345 von 100]
# Number of saved pictures: [346 von 100]
# Number of saved pictures: [347 von 100]
# Number of saved pictures: [348 von 100]
# Number of saved pictures: [349 von 100]
# Number of saved pictures: [350 von 100]
# Number of saved pictures: [351 von 100]
# Number of saved pictures: [352 von 100]
# Number of saved pictures: [353 von 100]
# Number of saved pictures: [354 von 100]
# Number of saved pictures: [355 von 100]
# Number of saved pictures: [356 von 100]
# Number of saved pictures: [357 von 100]
# Number of saved pictures: [358 von 100]
# Number of saved pictures: [359 von 100]
# Number of saved pictures: [360 von 100]
# Number of saved pictures: [361 von 100]
# Number of saved pictures: [362 von 100]
# Number of saved pictures: [363 von 100]
# Number of saved pictures: [364 von 100]
# Number of saved pictures: [365 von 100]
# Number of saved pictures: [366 von 100]
# Number of saved pictures: [367 von 100]
# Number of saved pictures: [368 von 100]
# Number of saved pictures: [369 von 100]
# Number of saved pictures: [370 von 100]
# Number of saved pictures: [371 von 100]
# Number of saved pictures: [372 von 100]
# Number of saved pictures: [373 von 100]
# Number of saved pictures: [374 von 100]
# Number of saved pictures: [375 von 100]
# Number of saved pictures: [376 von 100]
# Number of saved pictures: [377 von 100]
# Number of saved pictures: [378 von 100]
# Number of saved pictures: [379 von 100]
# Number of saved pictures: [380 von 100]
# Number of saved pictures: [381 von 100]
# Number of saved pictures: [382 von 100]
# Number of saved pictures: [383 von 100]
# Number of saved pictures: [384 von 100]
# Number of saved pictures: [385 von 100]
# Number of saved pictures: [386 von 100]
# Number of saved pictures: [387 von 100]
# Number of saved pictures: [388 von 100]
# Number of saved pictures: [389 von 100]
# Number of saved pictures: [390 von 100]
# Number of saved pictures: [391 von 100]
# Number of saved pictures: [392 von 100]
# Number of saved pictures: [393 von 100]
# Number of saved pictures: [394 von 100]
# Number of saved pictures: [395 von 100]
# Number of saved pictures: [396 von 100]
# Number of saved pictures: [397 von 100]
# Number of saved pictures: [398 von 100]
# Number of saved pictures: [399 von 100]
# Number of saved pictures: [400 von 100]
# Number of saved pictures: [401 von 100]
# Number of saved pictures: [402 von 100]
